# %%
import pandas as pd

# %%
#Table 2
t2 = pd.read_csv('./table_s2.csv')

# %%
t2 = t2.drop(['Accession', 'Description'], axis=1)
t2
# Out:
#      Gene Symbol  Sum_Coverage  Sum_Num Proteins  Sum_Num Unique Peptides  \
# 0         TUBB2B         77.08                 3                        2
# 1         TUBB2A         77.08                 3                        2
# 2           TUBB         77.25                11                        6
# 3         TUBB4B         71.01                 9                        2
# 4          TUBB3         74.44                12                       15
# ...          ...           ...               ...                      ...
# 1472       NOC2L          1.74                 1                        1
# 1473       KIF3A          1.57                 5                        1
# 1474      PCDHB9          1.88                 2                        1
# 1475        NPTN          6.47                 8                        1
# 1476       WASF2          2.61                 1                        1
#
#       Sum_Num Peptides  Sum_Num PSMs  Score A2  Coverage A2  Num Peptides A2  \
# ...

# %%
t2 = t2.sort_values('Gene Symbol')

# %%
t2
# Out:
#      Gene Symbol  Sum_Coverage  Sum_Num Proteins  Sum_Num Unique Peptides  \
# 604         AAK1         11.13                 3                        6
# 1322      ABCC12         10.38                 7                        1
# 1356       ABCF1          3.02                 3                        1
# 685         ABI1         10.31                16                        2
# 447         ABI2         18.74                17                        5
# ...          ...           ...               ...                      ...
# 18           NaN         13.98                 1                        1
# 1018         NaN         10.43                 4                        1
# 1020         NaN          4.28                 2                        2
# 1081         NaN          3.06                 1                        1
# 1328         NaN          7.38                 2                        1
#
#       Sum_Num Peptides  Sum_Num PSMs  Score A2  Coverage A2  Num Peptides A2  \
# ...

# %%
t2.to_csv('./table_s2.csv', index=False)

# %%
#Table 3
t3 = pd.read_csv('./table_s3.csv')
#t3 = t3.drop(['Accession', 'Description'], axis=1)
t3 = t3.sort_values('Gene Symbol')
t3.to_csv('./table_s3.csv', index=False)

# %%
t4 = pd.read_csv('./table_s4.csv')
#t4 = t4.drop(['Protein Name'], axis=1)
t4 = t4.sort_values('Gene Symbol')
t4.to_csv('./table_s4.csv', index=False)

# %%
t5 = pd.read_csv('./table_s5.csv')
#t5 = t5.drop(['Protein_name'], axis=1)
t5 = t5.sort_values('Gene Symbol')
t5.to_csv('./table_s5.csv', index=False)
